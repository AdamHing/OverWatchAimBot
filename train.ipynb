# %%
# !pip install roboflow
# !pip install opencv-python
# !pip install pandas
# !pip install ultralytics
# Out:
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# ...
#   Using cached ultralytics-8.2.10-py3-none-any.whl.metadata (40 kB)
# ...
#   Using cached torch-2.3.0-cp311-cp311-win_amd64.whl.metadata (26 kB)
# ...
#   Using cached torchvision-0.18.0-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached fsspec-2024.3.1-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached mkl-2021.4.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# ...
#   Using cached MarkupSafe-2.1.5-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# ...
# Using cached ultralytics-8.2.10-py3-none-any.whl (755 kB)
# ...

# %%
# !pip install torch

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#   Using cached https://download.pytorch.org/whl/cu121/torch-2.3.0%2Bcu121-cp311-cp311-win_amd64.whl (2413.3 MB)
# ...
#      ---------------------------------------- 0.0/5.7 MB ? eta -:--:--
#      ---- ----------------------------------- 0.7/5.7 MB 13.7 MB/s eta 0:00:01
#      ---------------------------- ----------- 4.1/5.7 MB 43.1 MB/s eta 0:00:01
#      ---------------------------------------- 5.7/5.7 MB 51.9 MB/s eta 0:00:00
# ...

# %%
import os
# os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
#os.environ['TORCH_USE_CUDA_DSA'] = "1"

# %%
# import pandas as pd
# import numpy as np
# import cv2
from ultralytics import YOLO
import torch

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="oxyNVIZpsPtsTkM7jAoP")
project = rf.workspace("overwatch1").project("overwatch2-swsia")
version = project.version(1)
dataset = version.download("yolov8-obb")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="oxyNVIZpsPtsTkM7jAoP")
project = rf.workspace("overwatch1").project("overwatch2-swsia")
version = project.version(1)
dataset = version.download("coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import yaml

with open(f'{dataset.location}\data.yaml', 'r') as file:
    data = yaml.safe_load(file)

data['path'] = dataset.location

with open(f'{dataset.location}\data.yaml', 'w') as file:
    yaml.dump(data, file, sort_keys=False)

# %%
def get_num_files(dir_path):
    return len([entry for entry in os.listdir(dir_path) if os.path.isfile(os.path.join(dir_path, entry))])

print("test",get_num_files(r'D:\Coding\Projects\OverWatchCV\overwatch2-1\test\images'))
print("train",get_num_files(r'D:\Coding\Projects\OverWatchCV\overwatch2-1\train\images'))
print("valid",get_num_files(r'D:\Coding\Projects\OverWatchCV\overwatch2-1\valid\images'))
print("bigtrain",get_num_files(r'D:\Coding\Projects\OverWatchCV\overwatch2-1\bigtrain\images'))
# Out:
# test 2200
# train 5601
# valid 2199
# bigtrain 7800

# %%
print(torch.cuda.device_count())
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# 1
# cuda

# %%
# print(model)
# print(model.info())
# print("cuda:",next(model.parameters()).is_cuda)
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# change head

# %%
dataset='overwatch2-1\data.yaml'

# %%
model = YOLO('BaseModels/yolov8s.pt')
model.to(device)
model.train(data = dataset, epochs = 5, batch=-1, freeze = 5, imgsz=640, amp=False)
# Out:
# New https://pypi.org/project/ultralytics/8.2.15 available  Update with 'pip install -U ultralytics'
# ...

# %% [markdown]
# test model

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO(r'D:\Coding\Projects\OverWatchCV\runs\detect\train9\weights\best.pt')  # pretrained YOLOv8n model
model = YOLO(r'D:\Coding\Projects\OverWatchCV\runs\detect\train16\weights\best.pt')
# Run batched inference on a list of images
results = model([ r'D:\Coding\Projects\OverWatchCV\overwatch2-1\valid\images\SRM_hanamura_mp4-138_jpg.rf.78219312db4571f87927eab9b1ff49c7.jpg'])  # return a list of Results objects

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    masks = result.masks  # Masks object for segmentation masks outputs
    keypoints = result.keypoints  # Keypoints object for pose outputs
    probs = result.probs  # Probs object for classification outputs
    obb = result.obb  # Oriented boxes object for OBB outputs
    result.show()  # display to screen
    result.save(filename='result.jpg')  # save to disk
    
print("=====================")
print(boxes)
print("=====================")
print(masks)
print("=====================")
print(keypoints)
print("=====================")
print(probs)
print("=====================")
print(obb)
# Out:
# 0: 640x640 1 SOLDIER-76, 2 ZARYAs, 52.0ms
# Speed: 4.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# ...
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([11., 11.,  7.], device='cuda:0')
# conf: tensor([0.3927, 0.2796, 0.2713], device='cuda:0')
# data: tensor([[3.1598e+02, 3.1371e+02, 3.2920e+02, 3.5752e+02, 3.9271e-01, 1.1000e+01],
#         [3.0907e+02, 3.0970e+02, 3.2881e+02, 3.5979e+02, 2.7963e-01, 1.1000e+01],
#         [3.0185e+02, 3.0281e+02, 3.1726e+02, 3.6208e+02, 2.7125e-01, 7.0000e+00]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([3, 6])
# xywh: tensor([[322.5931, 335.6168,  13.2178,  43.8145],
#         [318.9407, 334.7432,  19.7368,  50.0878],
#         [309.5548, 332.4468,  15.4022,  59.2673]], device='cuda:0')
# xywhn: tensor([[0.5041, 0.5244, 0.0207, 0.0685],
#         [0.4983, 0.5230, 0.0308, 0.0783],
# ...

# %%
model = YOLO("yolov8n.pt")
dict_classes = model.model.names
model.to(device)
# model.to("cuda")
print(dict_classes)
print(len(dict_classes))
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'micr
# ...

# %% [markdown]
# Metrics

# %%
import pandas as pd
from matplotlib import pyplot as plt
import os
import re
import numpy as np

# %%
#get latest run
runs = os.listdir(r"D:\Coding\Projects\OverWatchCV\runs\detect")
i = [y.replace("train","") for y in runs]
i = np.array(list(filter(None,i)),dtype=int)
print(max(i))

data = pd.read_csv(r"D:\Coding\Projects\OverWatchCV\runs\detect\train"+str(max(i))+r"\results.csv")
df = pd.DataFrame(data)
df
# Out:
# 30
#                   epoch           train/box_loss           train/cls_loss  \
# 0                     1                      nan                      nan
# 1                     2                      nan                      nan
# 2                     3                      nan                      nan
# 3                     4                      nan                      nan
# 4                     5                      nan                      nan
#
#             train/dfl_loss  metrics/precision(B)     metrics/recall(B)  \
# 0                      nan               0.00397               0.00043
# 1                      nan               0.00397               0.00043
# 2                      nan               0.00397               0.00043
# 3                      nan               0.00397               0.00043
# 4                      nan               0.00397               0.00043
#
#        metrics/mAP50(B)   metrics/mAP50-95(B)             val/box_loss  \
# ...

# %%
epoch=df["                  epoch"]
box_loss=df["         train/box_loss"]
cls_loss=df["         train/cls_loss"]
dfl_loss=df["         train/dfl_loss"]

# %%
#D:\Coding\Projects\OverWatchCV\runs\detect\train16\results.csv
# print(epoch)
# print(box_loss)
plt.plot(epoch,box_loss)
plt.plot(epoch,cls_loss)
plt.plot(epoch,dfl_loss)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name:                   epoch, dtype: int64
# 0                        nan
# 1                        nan
# 2                        nan
# 3                        nan
# 4                        nan
# Name:          train/box_loss, dtype: object
